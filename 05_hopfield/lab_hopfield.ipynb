% %%
x = linspace(1, 10, 10);

for i = 1:10
    subplot(2, 4, i)
    plot(x)
end
% Out:
% error: subplot: INDEX value must be >= 1 and <= ROWS*COLS
% error: called from
%     subplot at line 165 column 7
